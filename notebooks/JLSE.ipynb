# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
import mplhep as hep
plt.style.use(hep.style.CMS)

# %%
matplotlib.__version__
# Out:
# '3.7.1'

# %%
fig, ax = plt.subplots(figsize=(12,8))
plt.tight_layout()

widths = np.array([5,6,6])
xlabels = [
           "HIP",
           "Alpaka:HIP",
           "Kokkos:HIP",
           "SYCL:HIP"
          ]

data      = np.array([3.86e-10 ,3.12e-10,8.42E-10,1.16E-08])
dataErr   = np.array([8.24e-13,1.15e-12,1.58e-12 ,4.81E-10])
dataErrPct=dataErr/data
data = 1./data
dataErr = dataErrPct*data

data_fraction = [ '%s %%'%d for d in np.round(100*data/data[0],2)]
x_pos = np.arange(len(xlabels))

print(x_pos)
# print(np.round(data/data[0],2)*)
ax.legend(title="p2r benchmark:\nTested on AMD MI-100\nROCm-5.2.0",fontsize="xx-large")

bars = ax.bar(x_pos,data,yerr=dataErr,width=0.5)
ax.bar_label(bars, labels=data_fraction)
ax.set_xticks(x_pos)
ax.set_xticklabels(xlabels)
ax.set_xlabel("Portability Technologies")
# ax.set_ylim(0,6.5e6)
ax.set_ylim(1e7,1e11)
ax.set_yscale("log")
ax.set_ylabel("Throughput (tracks/s)")

plt.show()
plt.tight_layout()
fig.savefig("AMD-JLSE.pdf",bbox_inches = 'tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [0 1 2 3]

# %%
fig, ax = plt.subplots(figsize=(12,8))

widths = np.array([5,6,6])
xlabels = [
           "CUDA",
           "Alpaka",
           "Kokkos",
           "SYCL",
           "std::par"
          ]

data      = np.array([3.29E-10,3.75E-10,3.28E-10,3.44E-09,7.46E-10])
dataErr   = np.array([3.55E-13,1.17E-13,1.04E-13,5.58E-12,1.48E-10])
dataErrPct=dataErr/data
data = 1./data
dataErr = dataErrPct*data

data_fraction = [ '%s %%'%d for d in np.round(100*data/data[0],2)]
x_pos = np.arange(len(xlabels))

print(x_pos)
# print(np.round(data/data[0],2)*)
#ax.legend(title="p2r benchmark:\nTested on A100\nCUDA-11.6,bsize=32",fontsize="xx-large")
ax.legend(title="p2r benchmark:\nTested on A100 GPU\nKernel execution time only")


bars = ax.bar(x_pos,data,yerr=dataErr,width=0.5)
ax.bar_label(bars, labels=data_fraction)
ax.set_xticks(x_pos)
ax.set_xticklabels(xlabels)
ax.set_xlabel("Portability Technologies")
# ax.set_ylim(0,6.5e6)
ax.set_ylim(1e7,1e11)
ax.set_yscale("log")
ax.set_ylabel("Throughput (tracks/s)")

# plt.show()
# plt.tight_layout()
fig.savefig("p2r-GPU-KernelOnly.pdf",bbox_inches = 'tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [0 1 2 3 4]

# %%
fig, ax = plt.subplots(figsize=(8,6))
plt.tight_layout()

x = np.array([1,2,4,8,24,32,48,64,80,96])
y_tbb     = 1./np.array([2.321E-06,1.164E-06,5.7222E-07,2.86E-07,1.196E-07,1.0188E-07,8.657E-08,7.559E-08,4.991E-08,4.969E-08])
y_tbb_icc = 1./np.array([5.559E-07,2.75E-07 ,1.38E-07  ,7.32E-08,3.279E-08,3.0709E-08,1.924E-08,1.817E-08,1.957E-08,3.33E-08])


ax.errorbar(x,y_tbb,label="TBB(gcc)",marker="x",markersize=10)
# ax.errorbar(x,y_tbb_icc,label="TBB(icc)",marker="x",markersize=10)
ax.errorbar(96,1/5.1e-8,label="Kokkos(OMP)",marker="x",markersize=10)


ax.set_ylabel("Throughput (tracks/s)")
ax.set_xlabel("CPU threads")
# ax.set_yscale("log")
ax.legend(loc=2)
ax.set_ylim(0,ax.get_ylim()[1]*1.5)
ax.text(0,ax.get_ylim()[1]*0.5,"Tested on 2x Xeon Gold 6336Y\n bsize=32",fontsize="small")

plt.show()
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(12,8))

widths = np.array([5,6,6])
xlabels = [
           "TBB",
           # "TBB(bsize128)",    
           "Alpaka:TBB",    
           "Kokkos:OMP",    
           "SYCL",
           "std::par"
          ]

# data     = np.array([4.969E-08,5.1e-8,5.347e-08])
# data     = np.array([4.441e-08,5.530e-08,5.220e-08])
# data     = np.array([4.441e-08,5.073e-08,5.530e-08,5.220e-08])
# dataErr  = np.array([2.47e-10,2.45e-10,4.58e-10,1.52e-09])

data   =np.array([4.427e-08,5.180e-08,5.441e-08,1.881e-07,1.905e-07])
dataErr=np.array([2.52e-10  ,3.51e-10,1.13e-09,2.78e-10,2.44e-08])



dataErrPct=dataErr/data
data = 1./data
dataErr = dataErrPct*data


data_fraction = [ '%s %%'%d for d in np.round(100*data/data[0],2)]
x_pos = np.arange(len(xlabels))

print(x_pos)

ax.legend(title="p2r benchmark:\nTested on 2x Xeon Gold 6336Y")

bars = ax.bar(x_pos,data,yerr=dataErr,width=0.5)
ax.bar_label(bars, labels=data_fraction)
ax.set_xticks(x_pos)
ax.set_xticklabels(xlabels)
ax.set_xlabel("Portability Technologies")
# ax.set_ylim(0,6.5e6)
# ax.set_ylim(1e7,5e10)
ax.set_ylim(None,ax.get_ylim()[1]*1.5)
# ax.set_yscale("log")
ax.set_ylabel("Throughput (tracks/s)")

# plt.show()
# plt.tight_layout()
fig.savefig("p2r-CPU.pdf",bbox_inches = 'tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [0 1 2 3 4]

# %%
def readoutput(fin):
    with open(fin,'r') as f:
        for line in f:
            m = result_re.search(line)
            if m:
               #result.append( int(m.group("ntracks"))/float(m.group("time")))
               result.append( float(m.group("time"))/int(m.group("ntracks")))
    return result

# %%
# tbb =  [ 5.95578613e-08, 5.37968750e-08, 5.26630859e-08, 6.53583984e-08,
#             6.73210449e-08, 6.41696777e-08, 6.47880859e-08, 5.12917480e-08,
#             5.10192871e-08, 5.03923340e-08, 6.35527344e-08, 6.42121582e-08,
#             5.13588867e-08, 5.26008301e-08, 6.11469727e-08, 5.09406738e-08,
#             5.79296875e-08, 6.10048828e-08, 5.17900391e-08, 5.24013672e-08,] 
# alpaka =  [5.33838257e-08, 5.41923767e-08, 5.36327332e-08, 5.38351685e-08,
#             5.33582397e-08, 5.35527710e-08, 5.32879150e-08, 5.30467163e-08,
#             5.39805115e-08, 5.34508179e-08, 5.38956299e-08, 5.37734985e-08,
#             5.34394958e-08, 5.37958984e-08, 5.34978943e-08, 5.35142944e-08,
#             5.32692993e-08, 5.32145203e-08, 5.35226746e-08, 5.35184265e-08,] 


# tbb =  [4.49155762e-08, 4.43939575e-08, 4.43375793e-08, 4.41901978e-08,
#             4.42990051e-08, 4.44442932e-08, 4.44853577e-08, 4.47316956e-08,
#             4.41650208e-08, 4.45936829e-08, 4.44936584e-08, 4.46545898e-08,
#             4.46781677e-08, 4.42303467e-08, 4.46222961e-08, 4.40297791e-08,
#             4.40527344e-08, 4.46007935e-08, 4.40688171e-08, 4.41824158e-08,] 
# alpaka =  [5.13412354e-08, 5.19202026e-08, 5.20799316e-08, 5.21827637e-08,
#             5.16792664e-08, 5.19508240e-08, 5.20283020e-08, 5.22756348e-08,
#             5.25052856e-08, 5.27929871e-08, 5.25741455e-08, 5.26324646e-08,
#             5.28729553e-08, 5.24215149e-08, 5.14073975e-08, 5.20958435e-08,
# %%
fig,ax = plt.subplots(figsize=(12,8))
ax.plot(1./np.array(tbb),label="tbb")
ax.plot(1./np.array(alpaka),label="alpaka(tbb)")
ax.plot(1./np.array(kokkos),label="kokkos(omp)")
ax.plot(1./np.array(stdpar),label="stdpar(nvcc)")
ax.plot(1./np.array(sycl),label="sycl")
# ax.plot(1./np.array(kokkos2),label="kokkos(omp)")
ax.set_xlabel("Run number")
ax.set_ylabel("Track/s")

ax.legend(title="NITER=200,bsize=32")

# %%
fig, ax = plt.subplots(figsize=(12,8))

widths = np.array([5,6,6])
xlabels = [
           "SYCL",
           "Kokkos:SYCL",    
           "std::par(dpl)"
          ]
# DP emulation
# data   =np.array([2.821e-07,2.306e-06,1.813e-07])
# dataErr=np.array([6.12e-08 ,7.57e-09,2.78e-09])

# No DP emulation
data   =np.array([9.421e-09,1.447e-06,2.596e-08])
dataErr=np.array([6.51e-11,4.49e-09,1.39e-09])


dataErrPct=dataErr/data
data = 1./data
dataErr = dataErrPct*data


data_fraction = [ '%s %%'%d for d in np.round(100*data/data[0],2)]
x_pos = np.arange(len(xlabels))

print(x_pos)

ax.legend(title="p2r benchmark:\nTested on Intel A770 GPU",fontsize="xx-large")

bars = ax.bar(x_pos,data,yerr=dataErr,width=0.5)
ax.bar_label(bars, labels=data_fraction)
ax.set_xticks(x_pos)
ax.set_xticklabels(xlabels)
ax.set_xlabel("Portability Technologies")
# ax.set_ylim(0,6.5e6)
ax.set_ylim(1e4,5e10)
#ax.set_ylim(None,ax.get_ylim()[1]*1.5)
ax.set_yscale("log")
ax.set_ylabel("Throughput (tracks/s)")

# plt.show()
# plt.tight_layout()
fig.savefig("Intel-A770.pdf",bbox_inches = 'tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [0 1 2]

# %%
# Set the width of the bars
width = 0.35

x      = [1,1+width,1+3*width,1+4*width,1+6*width,1+7*width]

xticks = [1+0.5*width,1+3.5*width,1+6.5*width]

fig, ax = plt.subplots(figsize=(12,8))

xlabels = [
           "SYCL",
           "Kokkos(SYCL)",    
           "std::par(dpl)"
          ]

data   =np.array([2.821e-07,9.421e-09,
                  2.306e-06,7.315e-07,
                  1.813e-07,2.596e-08])
dataErr=np.array([6.12e-08,6.51e-11,
                  7.57e-09,3.10e-09,
                  2.78e-09,1.39e-09])

dataErrPct=dataErr/data
data = 1./data
dataErr = dataErrPct*data


data_fraction = [ '%s %%'%d for d in np.round(100*data[1::2]/data[::2],1)]
# data_fraction_even = [ '%s %%'%d for d in np.round(100*data[1::2]/data[1],2)]


# bars = ax.bar(x_pos,data,yerr=dataErr,width=0.5)


odd = ax.bar(x[::2] , data[::2], width, yerr=dataErr[::2],label="w/ doubleEmu")
even = ax.bar(x[1::2] , data[1::2],  width,yerr=dataErr[1::2],label="w/o doubleEmu")

ax.legend(title="p2r benchmark:\nTested on IntelGPU-A770\n bsize=32")

# ax.bar_label(odd, labels=data_fraction)
ax.bar_label(even, labels=data_fraction)
ax.set_xticks(xticks)
ax.set_xticklabels(xlabels)
ax.set_xlabel("Portability Technologies")
# ax.set_ylim(0,6.5e6)
ax.set_ylim(1e5,5e9)
ax.set_ylim(None,ax.get_ylim()[1]*1.5)
ax.set_yscale("log")
ax.set_ylabel("Throughput (tracks/s)")


# plt.show()
# plt.tight_layout()
fig.savefig("Intel-DP_Emu.pdf",bbox_inches = 'tight')
